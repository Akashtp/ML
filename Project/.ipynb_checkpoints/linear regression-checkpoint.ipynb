# %% [markdown]
# Linear regression

# %%
matplotlib inline

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("Book.xlsx", usecols = 'A,E,F,G,J' )
data
# Out:
#                           Name          Account Joining\nlocation  \
# 0               Akansha Saxena               GE         Bangalore
# 1              Suryaprakash E            Invidi           Chennai
# 2                 Vinosh Yalla      Multichoice         Bangalore
# 3                     Vinoth P           Invidi           Chennai
# 4                     Balaji J           Invidi           Chennai
# 5             Manisankar Dixit              ABB         Bangalore
# 6              D Remi Prasanna           Invidi           Chennai
# 7   Vaishnavi Ashokrao Umrekar              ABB         Bangalore
# 8         Suganthi Janakiraman              ABB         Bangalore
# 9                   Nageshwari      Multichoice         Bangalore
# 10        Naresh Kumar Kanakam      Multichoice         Bangalore
# 11                  Sherin M K      Multichoice         Bangalore
# 12          Minhajuddin Ahmed               ABB         Bangalore
# ...

# %%
X = data.iloc[:, ]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              18 non-null     object
#  1   Offered Date      18 non-null     datetime64[ns]
#  2   Experience        18 non-null     object
#  3   Skill set         18 non-null     object
#  4   Account           18 non-null     object
#  5   Joining
# location  18 non-null     object
#  6   Status            18 non-null     object
#  7   Mobile Number     18 non-null     object
#  8   Recruiter         18 non-null     object
#  9   Quarter           18 non-null     object
#  10  Joining Date      18 non-null     datetime64[ns]
#  11  Competency        18 non-null     object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 1.8+ KB

# %%
data.head()
# Out:
#               Name Offered Date Experience    Status
# 0   Akansha Saxena   2020-04-22        5.2    Joined
# 1  Suryaprakash E    2020-06-01        6.6    Joined
# 2     Vinosh Yalla   2021-06-23          4    Joined
# 3         Vinoth P   2020-06-30        5.4  Declined
# 4         Balaji J   2020-07-08       11.8    Joined

# %%
data[['Name']].describe()
# Out:
#                   Name
# count               18
# unique              18
# top     Akansha Saxena
# freq                 1

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transfromers = [('encoder', OneHotEncoder(), [])], remainder=)
